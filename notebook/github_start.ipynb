# %%
# %cd /content
# !rm -rf Audio-restoration
# !git clone https://github.com/Valalepi/Audio-restoration.git
# %cd /content/Audio-restoration
# !git status
# !git remote -v
# Out:
# /content
# Cloning into 'Audio-restoration'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# /content/Audio-restoration
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# origin	https://github.com/Valalepi/Audio-restoration.git (fetch)
# origin	https://github.com/Valalepi/Audio-restoration.git (push)

# %%
# !git config --global user.name "Valalepi"
# !git config --global user.email "valalepicollab@gmail.com"

# %%
import getpass, os
os.environ["GITHUB_TOKEN"] = getpass.getpass("Incolla il PAT e premi Invio: ")
# Out:
# Incolla il PAT e premi Invio: ··········

# %%
# %cd /content/Audio-restoration

# (opzionale ma consigliato) allinea la branch a main
# !git branch -M main

# !git add .
# !git commit -m "WIP: setup from Colab" || true

# !git push https://Valalepi:${GITHUB_TOKEN}@github.com/Valalepi/Audio-restoration.git main
# Out:
# /content/Audio-restoration
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# To https://github.com/Valalepi/Audio-restoration.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/Valalepi/Audio-restoration.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
import os
print("Token set:", "GITHUB_TOKEN" in os.environ)
print("Token length:", len(os.environ.get("GITHUB_TOKEN","")))
# Out:
# Token set: True
# Token length: 93

# %%
# %cd /content
# !rm -rf Audio-restoration
# !git clone https://github.com/Valalepi/Audio-restoration.git
# %cd /content/Audio-restoration
# !ls -la
# Out:
# /content
# Cloning into 'Audio-restoration'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), done.
# /content/Audio-restoration
# total 20
# drwxr-xr-x 3 root root 4096 Dec 24 11:11 .
# drwxr-xr-x 1 root root 4096 Dec 24 11:11 ..
# drwxr-xr-x 8 root root 4096 Dec 24 11:11 .git
# -rw-r--r-- 1 root root  304 Dec 24 11:11 .gitignore
# -rw-r--r-- 1 root root   74 Dec 24 11:11 README.md

# %%
# Contenuto del file .gitignore
gitignore_content = """
# Data/audio (restano su Drive)
data/
*.wav
*.mp3
*.flac
*.ogg

# Training artifacts (pesanti)
checkpoints/
models/
results/
runs/
*.pt
*.pth
*.ckpt

# Notebook / python cache
.ipynb_checkpoints/
__pycache__/
*.pyc

# Secrets
.env
"""

# Scrittura del file
with open(".gitignore", "w") as f:
    f.write(gitignore_content.strip())

print("✅ File .gitignore creato correttamente!")
# Out:
# ✅ File .gitignore creato correttamente!

# %%
import os

# 1. Crea le cartelle
folders = ["src", "notebooks"]
for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f"📂 Cartella creata: {folder}")

# 2. Crea i file vuoti nella root
root_files = ["README.md", "requirements.txt", "config.yaml"]
for file in root_files:
    with open(file, "w") as f:
        pass # Crea solo il file vuoto
    print(f"📄 File creato: {file}")

# 3. Crea i file vuoti dentro la cartella src
src_files = ["data.py", "models.py", "train.py", "metrics.py", "inference.py"]
for file in src_files:
    with open(os.path.join("src", file), "w") as f:
        pass
    print(f"📄 File creato in src: {file}")

print("\n✅ Struttura del progetto completata!")
# Out:
# 📂 Cartella creata: src
# 📂 Cartella creata: notebooks
# 📄 File creato: README.md
# 📄 File creato: requirements.txt
# 📄 File creato: config.yaml
# 📄 File creato in src: data.py
# 📄 File creato in src: models.py
# 📄 File creato in src: train.py
# 📄 File creato in src: metrics.py
# 📄 File creato in src: inference.py
#
# ✅ Struttura del progetto completata!

# %%
import getpass, os
os.environ["GITHUB_TOKEN"] = getpass.getpass("Incolla il PAT e premi Invio: ")
# Out:
# Incolla il PAT e premi Invio: ··········

# %%
# Sostituisci username e repo se servisse, ma dovrebbero essere giusti
username = "Valalepi"
repo = "Audio-restoration"

# !git pull origin main

github_url = f"https://oauth2:{os.environ.get('GITHUB_TOKEN')}@github.com/{username}/{repo}.git"

# !git push {github_url} main
# Out:
# From https://github.com/Valalepi/Audio-restoration
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (5/5), 609 bytes | 609.00 KiB/s, done.
# Total 5 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/Valalepi/Audio-restoration.git
#    312d077..81a539d  main -> main

# %%
# !git add .
# !git commit -m "Initial structure + gitignore"
# !git push origin main
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://github.com': No such device or address
